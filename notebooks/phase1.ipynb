# %%
# !pip uninstall -y dynamic-conversation dynamic_conversation
# !pip cache purge  # clears cached wheels
# !pip install --no-cache-dir git+https://github.com/Javin-Mendiratta/Dynamic-Conversation.git@main
# Out:
# WARNING: Skipping dynamic_conversation as it is not installed.
# WARNING: No matching packages
# Files removed: 0
# Collecting git+https://github.com/Javin-Mendiratta/Dynamic-Conversation.git@main
#   Cloning https://github.com/Javin-Mendiratta/Dynamic-Conversation.git (to revision main) to /tmp/pip-req-build-_vznk6nh
#   Running command git clone --filter=blob:none --quiet https://github.com/Javin-Mendiratta/Dynamic-Conversation.git /tmp/pip-req-build-_vznk6nh
#   Resolved https://github.com/Javin-Mendiratta/Dynamic-Conversation.git to commit e78e314d4d22e6dba37d21263cd4c94f6f98ad3c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (4.0.0)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (0.36.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (2.2.2)
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (2.0.2)
# Requirement already satisfied: transformers>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (4.57.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (2.9.0+cu126)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (0.22.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (4.67.1)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (6.0.3)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (25.0)
# Requirement already satisfied: filelock>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (3.20.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (0.13.2)
# Requirement already satisfied: plotly>=5.14.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.1) (5.24.1)
# Collecting jsonlines>=3.1.0 (from dynamic-conversation==0.1.1)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.1) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.1) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.1) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.1) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.16.4->dynamic-conversation==0.1.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.16.4->dynamic-conversation==0.1.1) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines>=3.1.0->dynamic-conversation==0.1.1) (25.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.1) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.1) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.1) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->dynamic-conversation==0.1.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->dynamic-conversation==0.1.1) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.14.0->dynamic-conversation==0.1.1) (9.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.1) (2025.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.1) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->dynamic-conversation==0.1.1) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->dynamic-conversation==0.1.1) (0.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (3.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->dynamic-conversation==0.1.1) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->dynamic-conversation==0.1.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->dynamic-conversation==0.1.1) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.1) (1.22.0)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Building wheels for collected packages: dynamic-conversation
#   Building wheel for dynamic-conversation (pyproject.toml) ... done
#   Created wheel for dynamic-conversation: filename=dynamic_conversation-0.1.1-py3-none-any.whl size=7229 sha256=f90e6d0d5cd2e47817c2d0f121db97b1d22014a6ef12e4fd27709f23230f3bd7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h01hn9p_/wheels/57/cd/2f/99075f7d11bcf410b468ec320f3fd004e1cfd89248cb13d2f0
# Successfully built dynamic-conversation
# Installing collected packages: jsonlines, dynamic-conversation
# Successfully installed dynamic-conversation-0.1.1 jsonlines-4.0.0

# %%
from dynamic_conversation import EmotionFlowAnalyzer
from datasets import load_dataset

# %%
"""Execute emotion flow analysis pipeline."""

# Load dataset
print("=" * 60)
print("EMOTION FLOW ANALYSIS - ESConv Dataset")
print("=" * 60)
print("\nLoading ESConv dataset...")
dataset = load_dataset("thu-coai/esconv")
print(f"✓ Dataset loaded with {len(dataset['train'])} conversations")

# Initialize analyzer
print("\n" + "=" * 60)
analyzer = EmotionFlowAnalyzer(use_gpu=True)

# Process conversations
print("\n" + "=" * 60)
analyzer.process_dataset(dataset, max_conversations=100)

if len(analyzer.conversation_emotions) == 0:
    raise Exception("Error: No conversations were successfully processed!")
    

# Compute transition matrix
print("\n" + "=" * 60)
print("Computing emotion transition matrix...")
transition_matrix = analyzer.compute_transition_matrix()
print("\nTransition Matrix:")
print(transition_matrix.round(3))

# Compute trajectory scores
print("\n" + "=" * 60)
print("Computing emotion trajectory scores...")
trajectory_scores = analyzer.compute_all_trajectory_scores()
print("\nTrajectory Scores (first 5 conversations):")
print(trajectory_scores.head())
# Out:
# ============================================================
# EMOTION FLOW ANALYSIS - ESConv Dataset
# ============================================================
#
# Loading ESConv dataset...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# README.md:   0%|          | 0.00/510 [00:00<?, ?B/s]
# train.txt: 0.00B [00:00, ?B/s]
# valid.txt: 0.00B [00:00, ?B/s]
# test.txt: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/910 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/195 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/195 [00:00<?, ? examples/s]
# ✓ Dataset loaded with 910 conversations
#
# ============================================================
# Loading emotion classifier: j-hartmann/emotion-english-distilroberta-base
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/329M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cuda:0
# ============================================================
# Processing conversations...
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Classifying emotions: 100%|██████████| 100/100 [00:16<00:00,  6.22it/s]
# Successfully processed 100 conversations
#
# ============================================================
# Computing emotion transition matrix...
#
# Transition Matrix:
#           anger  disgust   fear    joy  neutral  sadness  surprise
# anger     0.085    0.043  0.050  0.099    0.433    0.206     0.085
# disgust   0.051    0.137  0.111  0.068    0.325    0.197     0.111
# fear      0.060    0.046  0.176  0.097    0.389    0.199     0.032
# joy       0.017    0.018  0.046  0.347    0.402    0.103     0.066
# neutral   0.052    0.043  0.067  0.157    0.464    0.150     0.068
# sadness   0.058    0.032  0.070  0.109    0.376    0.270     0.085
# surprise  0.036    0.046  0.102  0.137    0.386    0.183     0.112
#
# ============================================================
# Computing emotion trajectory scores...
#
# Trajectory Scores (first 5 conversations):
#    conversation_id emotion_type           problem_type  anger_trajectory  \
# 0                0      anxiety             job crisis          0.039545
# 1                1   depression     ongoing depression          0.020815
# 2                2      anxiety             job crisis          0.013691
# 3                3   depression   breakup with partner          0.051432
# 4                4      disgust  problems with friends          0.123245
#
#    disgust_trajectory  fear_trajectory  joy_trajectory  neutral_trajectory  \
# 0            0.063650         0.231344        0.012596            0.383451
# 1            0.053108         0.095846        0.124686            0.473133
# 2            0.010755         0.021156        0.506297            0.309707
# 3            0.079020         0.082981        0.085687            0.310545
# 4            0.172691         0.055899        0.026792            0.532382
#
#    sadness_trajectory  surprise_trajectory
# 0            0.155864             0.113550
# 1            0.207109             0.025303
# 2            0.061696             0.076697
# 3            0.290179             0.100155
# 4            0.043253             0.045739
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-2554685677.py in <cell line: 0>()
#      36
#      37 # Save results
# ---> 38 trajectory_scores.to_csv('results/emotion_trajectory_scores.csv', index=False)
#      39 print("\n✓ Saved trajectory scores to emotion_trajectory_scores.csv")
#      40
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: 'results'

# %%
# Save results
trajectory_scores.to_csv('../results/emotion_trajectory_scores.csv', index=False)
print("\n✓ Saved trajectory scores to emotion_trajectory_scores.csv")

# Generate visualizations
print("\n" + "=" * 60)
print("Generating visualizations...")
print()

analyzer.plot_transition_heatmap()
analyzer.plot_sankey_diagram(conversation_id=0)
analyzer.plot_aggregate_emotion_flow()

# Summary
print("\n" + "=" * 60)
print("✓ ANALYSIS COMPLETE!")
print("=" * 60)
print(f"Processed: {len(analyzer.conversation_emotions)} conversations")
print("\nGenerated files:")
print("  📊 emotion_transition_heatmap.png")
print("  📈 emotion_sankey.html")
print("  📉 aggregate_emotion_flow.png")
print("  📄 emotion_trajectory_scores.csv")
print("=" * 60)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipython-input-2340039116.py in <cell line: 0>()
#       1 # Save results
# ----> 2 trajectory_scores.to_csv('../results/emotion_trajectory_scores.csv', index=False)
#       3 print("\n✓ Saved trajectory scores to emotion_trajectory_scores.csv")
#       4
#       5 # Generate visualizations
#
# /usr/local/lib/python3.12/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3965         )
#    3966
# -> 3967         return DataFrameRenderer(formatter).to_csv(
#    3968             path_or_buf,
#    3969             lineterminator=lineterminator,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1012             formatter=self.fmt,
#    1013         )
# -> 1014         csv_formatter.save()
#    1015
#    1016         if created_buffer:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/formats/csvs.py in save(self)
#     249         """
#     250         # apply compression and byte/text conversion
# --> 251         with get_handle(
#     252             self.filepath_or_buffer,
#     253             self.mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747     # Only for write methods
#     748     if "r" not in mode and is_path:
# --> 749         check_parent_directory(str(handle))
#     750
#     751     if compression:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     614     parent = Path(path).parent
#     615     if not parent.is_dir():
# --> 616         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     617
#     618
#
# OSError: Cannot save file into a non-existent directory: '../results'
