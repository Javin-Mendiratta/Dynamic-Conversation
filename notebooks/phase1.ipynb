# %%
# !pip install --no-cache-dir git+https://github.com/Javin-Mendiratta/Dynamic-Conversation.git@main
# Out:
# Collecting git+https://github.com/Javin-Mendiratta/Dynamic-Conversation.git@main
#   Cloning https://github.com/Javin-Mendiratta/Dynamic-Conversation.git (to revision main) to /tmp/pip-req-build-dc04p9s9
#   Running command git clone --filter=blob:none --quiet https://github.com/Javin-Mendiratta/Dynamic-Conversation.git /tmp/pip-req-build-dc04p9s9
#   Resolved https://github.com/Javin-Mendiratta/Dynamic-Conversation.git to commit 0cecaf64fff6ddef9b37a59434bf214b46f229fe
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: datasets>=2.14.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (4.0.0)
# Requirement already satisfied: huggingface-hub>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (0.36.0)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (2.2.2)
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (2.0.2)
# Requirement already satisfied: transformers>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (4.57.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (2.9.0+cu126)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (0.22.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (4.67.1)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (6.0.3)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (25.0)
# Requirement already satisfied: filelock>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (3.20.0)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (3.10.0)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (0.13.2)
# Requirement already satisfied: plotly>=5.14.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (5.24.1)
# Requirement already satisfied: jsonlines>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from dynamic-conversation==0.1.0) (4.0.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.0) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=2.14.0->dynamic-conversation==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.16.4->dynamic-conversation==0.1.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.16.4->dynamic-conversation==0.1.0) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonlines>=3.1.0->dynamic-conversation==0.1.0) (25.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->dynamic-conversation==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->dynamic-conversation==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.3->dynamic-conversation==0.1.0) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.14.0->dynamic-conversation==0.1.0) (9.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dynamic-conversation==0.1.0) (2025.11.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (3.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->dynamic-conversation==0.1.0) (3.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->dynamic-conversation==0.1.0) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->dynamic-conversation==0.1.0) (0.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (3.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->dynamic-conversation==0.1.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->dynamic-conversation==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->dynamic-conversation==0.1.0) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.14.0->dynamic-conversation==0.1.0) (1.22.0)
# Building wheels for collected packages: dynamic-conversation
#   Building wheel for dynamic-conversation (pyproject.toml) ... done
#   Created wheel for dynamic-conversation: filename=dynamic_conversation-0.1.0-py3-none-any.whl size=7229 sha256=52be7a76c5f0949bbaaeccd9affdac2b57d272af34b113f1a67758f53b020972
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5erlr0a8/wheels/57/cd/2f/99075f7d11bcf410b468ec320f3fd004e1cfd89248cb13d2f0
# Successfully built dynamic-conversation
# Installing collected packages: dynamic-conversation
# Successfully installed dynamic-conversation-0.1.0

# %%
import dynamic_conversation.load_data as ld
print(ld.__file__)
print(hasattr(ld, "EsConvData"))
from dynamic_conversation import EmotionFlowAnalyzer, EsConvData
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-4040772666.py in <cell line: 0>()
# ----> 1 import dynamic_conversation.load_data as ld
#       2 print(ld.__file__)
#       3 print(hasattr(ld, "EsConvData"))
#       4 from dynamic_conversation import EmotionFlowAnalyzer, EsConvData
#
# /usr/local/lib/python3.12/dist-packages/dynamic_conversation/__init__.py in <module>
#       2
#       3 from .emotion_map import EmotionFlowAnalyzer
# ----> 4 from .load_data import EsConvData
#       5
#       6 __all__ = ["EmotionFlowAnalyzer", "EsConvData"]
#
# ImportError: cannot import name 'EsConvData' from 'dynamic_conversation.load_data' (/usr/local/lib/python3.12/dist-packages/dynamic_conversation/load_data.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
ds = load_dataset("thu-coai/esconv")
analyzer = EmotionFlowAnalyzer(use_gpu=False)
analyzer.process_dataset(ds, max_conversations=50)
tm = analyzer.compute_transition_matrix()
trajectory = analyzer.compute_all_trajectory_scores()
analyzer.plot_transition_heatmap()
analyzer.plot_sankey_diagram(conversation_id=0)
analyzer.plot_aggregate_emotion_flow()

# %% [markdown]
# ### Pull Repo -- Execute whenever changes are made

# %%
# %cd /content/Dynamic-Conversation/
# !pip install .
# Out:
# /content/Dynamic-Conversation
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
import sys
sys.path.append("/content/Dynamic-Conversation/code/part1")

# %%
# Load data:
"""Execute emotion flow analysis pipeline."""

# Load dataset
print("=" * 60)
print("EMOTION FLOW ANALYSIS - ESConv Dataset")
print("=" * 60)
print("\nLoading ESConv dataset...")
dataset = load_dataset("thu-coai/esconv")
print(f"✓ Dataset loaded with {len(dataset['train'])} conversations")
# Out:
# ============================================================
# EMOTION FLOW ANALYSIS - ESConv Dataset
# ============================================================
#
# Loading ESConv dataset...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3137982133.py in <cell line: 0>()
#       7 print("=" * 60)
#       8 print("\nLoading ESConv dataset...")
# ----> 9 dataset = load_dataset("thu-coai/esconv")
#      10 print(f"✓ Dataset loaded with {len(dataset['train'])} conversations")
#
# NameError: name 'load_dataset' is not defined

# %%
def main():
    """Execute emotion flow analysis pipeline."""
    
    # Load dataset
    print("=" * 60)
    print("EMOTION FLOW ANALYSIS - ESConv Dataset")
    print("=" * 60)
    print("\nLoading ESConv dataset...")
    dataset = load_dataset("thu-coai/esconv")
    print(f"✓ Dataset loaded with {len(dataset['train'])} conversations")
    
    # Initialize analyzer
    print("\n" + "=" * 60)
    analyzer = EmotionFlowAnalyzer(use_gpu=True)
    
    # Process conversations
    print("\n" + "=" * 60)
    analyzer.process_dataset(dataset, max_conversations=100)
    
    if len(analyzer.conversation_emotions) == 0:
        print("\n❌ Error: No conversations were successfully processed!")
        return
    
    # Compute transition matrix
    print("\n" + "=" * 60)
    print("Computing emotion transition matrix...")
    transition_matrix = analyzer.compute_transition_matrix()
    print("\nTransition Matrix:")
    print(transition_matrix.round(3))
    
    # Compute trajectory scores
    print("\n" + "=" * 60)
    print("Computing emotion trajectory scores...")
    trajectory_scores = analyzer.compute_all_trajectory_scores()
    print("\nTrajectory Scores (first 5 conversations):")
    print(trajectory_scores.head())
    
    # Save results
    trajectory_scores.to_csv('results/emotion_trajectory_scores.csv', index=False)
    print("\n✓ Saved trajectory scores to emotion_trajectory_scores.csv")
    
    # Generate visualizations
    print("\n" + "=" * 60)
    print("Generating visualizations...")
    print()
    
    analyzer.plot_transition_heatmap()
    analyzer.plot_sankey_diagram(conversation_id=0)
    analyzer.plot_aggregate_emotion_flow()
    
    # Summary
    print("\n" + "=" * 60)
    print("✓ ANALYSIS COMPLETE!")
    print("=" * 60)
    print(f"Processed: {len(analyzer.conversation_emotions)} conversations")
    print("\nGenerated files:")
    print("  📊 emotion_transition_heatmap.png")
    print("  📈 emotion_sankey.html")
    print("  📉 aggregate_emotion_flow.png")
    print("  📄 emotion_trajectory_scores.csv")
    print("=" * 60)


if __name__ == "__main__":
    main()
